# %%
import numpy as np
import pandas as pd
import sys
import math
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix
from imblearn.over_sampling import RandomOverSampler

# %%
data_filename = 'AirQualityUCI.csv'
if sys.modules.get("google.colab") is None:
    data_path_prefix = "."
else:
    from google.colab import drive
    drive.mount("/content/drive")
    data_path_prefix = "/content/drive/MyDrive/MachineLearningAssignments/Assignment1"

data_path = f"{data_path_prefix}/{data_filename}"
print(f"Loading data from data path: {data_path}")
df = pd.read_csv(data_path, sep=';', na_values=-200)
df
# Out:
# Loading data from data path: ./AirQualityUCI.csv
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# 0          1268.0  13,6  48,9  0,7578          NaN          NaN
# 1           972.0  13,3  47,7  0,7255          NaN          NaN
# 2          1074.0  11,9  54,0  0,7502          NaN          NaN
# 3          1203.0  11,0  60,0  0,7867          NaN          NaN
# 4          1110.0  11,2  59,6  0,7888          NaN          NaN
# ...           ...   ...   ...     ...          ...          ...
# 9466          NaN   NaN   NaN     NaN          NaN          NaN
# 9467          NaN   NaN   NaN     NaN          NaN          NaN
# 9468          NaN   NaN   NaN     NaN          NaN          NaN
# 9469          NaN   NaN   NaN     NaN          NaN          NaN
# 9470          NaN   NaN   NaN     NaN          NaN          NaN
#
# [9471 rows x 17 columns]

# %%
# Show rows with missing values
df[df.loc[:,~df.columns.str.contains("Unnamed:")].isnull().any(axis=1)]
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 9     11/03/2004  03.00.00    0,6       1010.0      19.0      1,7
# 10    11/03/2004  04.00.00    NaN       1011.0      14.0      1,3
# 33    12/03/2004  03.00.00    0,8        889.0      21.0      1,9
# 34    12/03/2004  04.00.00    NaN        831.0      10.0      1,1
# 39    12/03/2004  09.00.00    NaN       1545.0       NaN     22,1
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9             561.0      NaN        1705.0      NaN        1235.0
# 10            527.0     21.0        1818.0     34.0        1197.0
# 33            574.0      NaN        1680.0      NaN        1187.0
# 34            506.0     21.0        1893.0     32.0        1134.0
# 39           1353.0      NaN         767.0      NaN        2058.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# 9           501.0  10,3  60,2  0,7517          NaN          NaN
# 10          445.0  10,1  60,5  0,7465          NaN          NaN
# 33          512.0   7,0  62,3  0,6261          NaN          NaN
# 34          384.0   6,1  65,9  0,6248          NaN          NaN
# 39         1588.0   9,2  56,2  0,6561          NaN          NaN
# ...           ...   ...   ...     ...          ...          ...
# 9466          NaN   NaN   NaN     NaN          NaN          NaN
# 9467          NaN   NaN   NaN     NaN          NaN          NaN
# 9468          NaN   NaN   NaN     NaN          NaN          NaN
# 9469          NaN   NaN   NaN     NaN          NaN          NaN
# 9470          NaN   NaN   NaN     NaN          NaN          NaN
#
# [8644 rows x 17 columns]

# %%
processed_df = df.copy()
processed_df.dropna(how='all', axis=1, inplace=True)
processed_df.dropna(how='all', axis=0, inplace=True)
for column in processed_df.columns[2:]:
    if processed_df[column].dtype == object:
        processed_df[column] = processed_df[column].str.replace(",", ".").astype(float)
processed_df["DateTime"] = pd.to_datetime(processed_df["Date"].str.cat(processed_df["Time"], sep=" "), format="%d/%m/%Y %H.%M.%S")
processed_df.drop(["Date", "Time"], axis=1, inplace=True)
# Show rows with missing values
processed_df[processed_df.isnull().any(axis=1)]
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 9        0.6       1010.0      19.0       1.7          561.0      NaN
# 10       NaN       1011.0      14.0       1.3          527.0     21.0
# 33       0.8        889.0      21.0       1.9          574.0      NaN
# 34       NaN        831.0      10.0       1.1          506.0     21.0
# 39       NaN       1545.0       NaN      22.1         1353.0      NaN
# ...      ...          ...       ...       ...            ...      ...
# 9352     3.1       1314.0       NaN      13.5         1101.0    472.0
# 9353     2.4       1163.0       NaN      11.4         1027.0    353.0
# 9354     2.4       1142.0       NaN      12.4         1063.0    293.0
# 9355     2.1       1003.0       NaN       9.5          961.0    235.0
# 9356     2.2       1071.0       NaN      11.9         1047.0    265.0
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  \
# 9           1705.0      NaN        1235.0        501.0  10.3  60.2  0.7517
# 10          1818.0     34.0        1197.0        445.0  10.1  60.5  0.7465
# 33          1680.0      NaN        1187.0        512.0   7.0  62.3  0.6261
# 34          1893.0     32.0        1134.0        384.0   6.1  65.9  0.6248
# 39           767.0      NaN        2058.0       1588.0   9.2  56.2  0.6561
# ...            ...      ...           ...          ...   ...   ...     ...
# 9352         539.0    190.0        1374.0       1729.0  21.9  29.3  0.7568
# 9353         604.0    179.0        1264.0       1269.0  24.3  23.7  0.7119
# 9354         603.0    175.0        1241.0       1092.0  26.9  18.3  0.6406
# 9355         702.0    156.0        1041.0        770.0  28.3  13.5  0.5139
# 9356         654.0    168.0        1129.0        816.0  28.5  13.1  0.5028
#
#                 DateTime
# 9    2004-03-11 03:00:00
# 10   2004-03-11 04:00:00
# 33   2004-03-12 03:00:00
# 34   2004-03-12 04:00:00
# 39   2004-03-12 09:00:00
# ...                  ...
# 9352 2005-04-04 10:00:00
# 9353 2005-04-04 11:00:00
# 9354 2005-04-04 12:00:00
# 9355 2005-04-04 13:00:00
# 9356 2005-04-04 14:00:00
#
# [8530 rows x 14 columns]

# %%
processed_df.isnull().sum()
# Out:
# CO(GT)           1592
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)            0
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# DateTime            0
# dtype: int64

# %%
processed_df.drop("DateTime", axis=1, inplace=True)
processed_df.drop("NMHC(GT)", axis=1, inplace=True)
processed_df.fillna(processed_df.mean(), inplace=True)
tag_column = "C6H6(GT)"
temp = processed_df.pop(tag_column)
processed_df[tag_column] = temp
processed_df
# Out:
#       CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# 0        2.6       1360.0         1046.0    166.0        1056.0    113.0
# 1        2.0       1292.0          955.0    103.0        1174.0     92.0
# 2        2.2       1402.0          939.0    131.0        1140.0    114.0
# 3        2.2       1376.0          948.0    172.0        1092.0    122.0
# 4        1.6       1272.0          836.0    131.0        1205.0    116.0
# ...      ...          ...            ...      ...           ...      ...
# 9352     3.1       1314.0         1101.0    472.0         539.0    190.0
# 9353     2.4       1163.0         1027.0    353.0         604.0    179.0
# 9354     2.4       1142.0         1063.0    293.0         603.0    175.0
# 9355     2.1       1003.0          961.0    235.0         702.0    156.0
# 9356     2.2       1071.0         1047.0    265.0         654.0    168.0
#
#       PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  C6H6(GT)
# 0           1692.0       1268.0  13.6  48.9  0.7578      11.9
# 1           1559.0        972.0  13.3  47.7  0.7255       9.4
# 2           1555.0       1074.0  11.9  54.0  0.7502       9.0
# 3           1584.0       1203.0  11.0  60.0  0.7867       9.2
# 4           1490.0       1110.0  11.2  59.6  0.7888       6.5
# ...            ...          ...   ...   ...     ...       ...
# 9352        1374.0       1729.0  21.9  29.3  0.7568      13.5
# 9353        1264.0       1269.0  24.3  23.7  0.7119      11.4
# 9354        1241.0       1092.0  26.9  18.3  0.6406      12.4
# 9355        1041.0        770.0  28.3  13.5  0.5139       9.5
# 9356        1129.0        816.0  28.5  13.1  0.5028      11.9
#
# [9357 rows x 12 columns]

# %%
def data_split(df):
    train_df, valid_and_test_df = train_test_split(df, train_size=0.7, random_state=0)
    valid_df, test_df = train_test_split(valid_and_test_df, train_size=0.5, random_state=0)
    return train_df, valid_df, test_df
train_df, valid_df, test_df = data_split(processed_df)
train_df
# Out:
#       CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# 8772     0.6        928.0          631.0    148.0         985.0     89.0
# 3594     1.2        929.0          811.0     57.0         862.0     67.0
# 3197     3.5       1239.0         1129.0    121.0         637.0    106.0
# 2819     0.7        913.0          743.0     65.0         931.0     66.0
# 9031     1.5       1069.0          799.0    181.0         682.0    121.0
# ...      ...          ...            ...      ...           ...      ...
# 7891     2.6       1037.0          981.0    388.0         721.0    139.0
# 9225     0.5        826.0          512.0     84.0        1108.0     61.0
# 4859     0.4        769.0          586.0     60.0        1221.0     45.0
# 3264     1.3       1034.0          812.0     70.0         866.0     82.0
# 2732     1.7       1099.0         1015.0    125.0         763.0    117.0
#
#       PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  C6H6(GT)
# 8772         908.0        884.0   4.5  56.3  0.4800       2.7
# 3594        1541.0        642.0  35.5  29.8  1.7004       6.0
# 3197        1839.0       1308.0  28.9  39.1  1.5370      14.4
# 2819        1540.0        884.0  21.8  52.3  1.3539       4.6
# 9031        1211.0       1044.0  12.6  67.9  0.9886       5.7
# ...            ...          ...   ...   ...     ...       ...
# 7891        1000.0       1086.0  13.7  20.7  0.3221      10.1
# 9225        1043.0        636.0  12.5  67.4  0.9722       1.1
# 4859        1134.0        650.0  17.1  52.5  1.0130       2.0
# 3264        1563.0        660.0  32.3  33.4  1.5900       6.0
# 2732        1732.0        839.0  38.8  20.7  1.4036      11.0
#
# [6549 rows x 12 columns]

# %%
scaler = StandardScaler()
scaler.fit(train_df)
def scale_dataset(scaler, classification_func=None):
    def func(df, oversample=False):
        data = scaler.transform(df)
        X = data[:,:-1]
        y = data[:,-1]
        if classification_func is not None:
            y = np.array([classification_func(item) for item in y])
            if oversample:
                ros = RandomOverSampler(random_state=0)
                X, y = ros.fit_resample(X, y)
        return data, X, y
    return func

# %%
scale_classification = scale_dataset(scaler, classification_func=lambda x: 1 if x > 0 else 0)
train, train_X, train_y = scale_classification(train_df, oversample=True)
valid, valid_X, valid_y = scale_classification(valid_df)
test, test_X, test_y = scale_classification(test_df)

# %%
best_knn = None
print(f"Length of train data: {len(train_X)}")
for k in range(1, int(math.sqrt(len(train_X)))):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(train_X, train_y)
    predicted_y = knn.predict(valid_X)
    auc = roc_auc_score(valid_y, predicted_y)
    print(f"Try k={k} on valid data, AUC: {auc}")
    if best_knn is None or auc > best_knn[0]:
        best_knn = (auc, k, knn)
print(f"Best k: {best_knn[1]}, AUC on valid data: {best_knn[0]}")
# Out:
# Length of train data: 11898
# Try k=1 on valid data, AUC: 0.9591796165420234
# Try k=2 on valid data, AUC: 0.9774305436548465
# Try k=3 on valid data, AUC: 0.9774305436548465
# Try k=4 on valid data, AUC: 0.9743321703008575
# Try k=5 on valid data, AUC: 0.9743321703008575
# Try k=6 on valid data, AUC: 0.9756585757079302
# Try k=7 on valid data, AUC: 0.9756585757079302
# Try k=8 on valid data, AUC: 0.9765976844457545
# Try k=9 on valid data, AUC: 0.9769849811150031
# Try k=10 on valid data, AUC: 0.9734993110917652
# Try k=11 on valid data, AUC: 0.9738866077610139
# Try k=12 on valid data, AUC: 0.9719501244147707
# Try k=13 on valid data, AUC: 0.9719501244147707
# Try k=14 on valid data, AUC: 0.9748257164988381
# Try k=15 on valid data, AUC: 0.9663634556459628
# Try k=16 on valid data, AUC: 0.9655888623074655
# Try k=17 on valid data, AUC: 0.9659761589767142
# Try k=18 on valid data, AUC: 0.967302564383787
# Try k=19 on valid data, AUC: 0.968464454391533
# Try k=20 on valid data, AUC: 0.9645914876990465
# Try k=21 on valid data, AUC: 0.9676898610530356
# Try k=22 on valid data, AUC: 0.9657533777067925
# Try k=23 on valid data, AUC: 0.9669152677145384
# Try k=24 on valid data, AUC: 0.9645914876990465
# Try k=25 on valid data, AUC: 0.9657533777067925
# Try k=26 on valid data, AUC: 0.9645914876990465
# Try k=27 on valid data, AUC: 0.9653660810375438
# Try k=28 on valid data, AUC: 0.9694035631293572
# Try k=29 on valid data, AUC: 0.9697908597986058
# Try k=30 on valid data, AUC: 0.9686289697908598
# Try k=31 on valid data, AUC: 0.9642041910297978
# Try k=32 on valid data, AUC: 0.9626550043528033
# Try k=33 on valid data, AUC: 0.9626550043528033
# Try k=34 on valid data, AUC: 0.9614931143450574
# Try k=35 on valid data, AUC: 0.9614931143450574
# Try k=36 on valid data, AUC: 0.9599439276680627
# Try k=37 on valid data, AUC: 0.9603312243373113
# Try k=38 on valid data, AUC: 0.9603312243373113
# Try k=39 on valid data, AUC: 0.9611058176758087
# Try k=40 on valid data, AUC: 0.9647560030983733
# Try k=41 on valid data, AUC: 0.9655305964368707
# Try k=42 on valid data, AUC: 0.9628195197521301
# Try k=43 on valid data, AUC: 0.963981409759876
# Try k=44 on valid data, AUC: 0.9624322230828815
# Try k=45 on valid data, AUC: 0.9624322230828815
# Try k=46 on valid data, AUC: 0.9620449264136328
# Try k=47 on valid data, AUC: 0.9635941130906274
# Try k=48 on valid data, AUC: 0.9628195197521301
# Try k=49 on valid data, AUC: 0.9632068164213787
# Try k=50 on valid data, AUC: 0.9612703330751355
# Try k=51 on valid data, AUC: 0.9612703330751355
# Try k=52 on valid data, AUC: 0.9608830364058869
# Try k=53 on valid data, AUC: 0.9620449264136328
# Try k=54 on valid data, AUC: 0.9612703330751355
# Try k=55 on valid data, AUC: 0.9612703330751355
# Try k=56 on valid data, AUC: 0.9608830364058869
# Try k=57 on valid data, AUC: 0.9608830364058869
# Try k=58 on valid data, AUC: 0.9604957397366383
# Try k=59 on valid data, AUC: 0.9608830364058869
# Try k=60 on valid data, AUC: 0.9593338497288924
# Try k=61 on valid data, AUC: 0.9593338497288924
# Try k=62 on valid data, AUC: 0.9585592563903951
# Try k=63 on valid data, AUC: 0.9589465530596437
# Try k=64 on valid data, AUC: 0.9585592563903951
# Try k=65 on valid data, AUC: 0.959721146398141
# Try k=66 on valid data, AUC: 0.9593338497288924
# Try k=67 on valid data, AUC: 0.959721146398141
# Try k=68 on valid data, AUC: 0.9577846630518978
# Try k=69 on valid data, AUC: 0.9585592563903951
# Try k=70 on valid data, AUC: 0.9577846630518978
# Try k=71 on valid data, AUC: 0.9577846630518978
# Try k=72 on valid data, AUC: 0.9566227730441519
# Try k=73 on valid data, AUC: 0.9566227730441519
# Try k=74 on valid data, AUC: 0.9558481797056546
# Try k=75 on valid data, AUC: 0.9558481797056546
# Try k=76 on valid data, AUC: 0.9546862896979086
# Try k=77 on valid data, AUC: 0.9546862896979086
# Try k=78 on valid data, AUC: 0.9546862896979086
# Try k=79 on valid data, AUC: 0.9546862896979086
# Try k=80 on valid data, AUC: 0.9539116963594113
# Try k=81 on valid data, AUC: 0.95429899302866
# Try k=82 on valid data, AUC: 0.95429899302866
# Try k=83 on valid data, AUC: 0.95429899302866
# Try k=84 on valid data, AUC: 0.9539116963594113
# Try k=85 on valid data, AUC: 0.9539116963594113
# Try k=86 on valid data, AUC: 0.9535243996901627
# Try k=87 on valid data, AUC: 0.9539116963594113
# Try k=88 on valid data, AUC: 0.9539116963594113
# Try k=89 on valid data, AUC: 0.95429899302866
# Try k=90 on valid data, AUC: 0.953137103020914
# Try k=91 on valid data, AUC: 0.953137103020914
# Try k=92 on valid data, AUC: 0.9527498063516654
# Try k=93 on valid data, AUC: 0.953137103020914
# Try k=94 on valid data, AUC: 0.9527498063516654
# Try k=95 on valid data, AUC: 0.9535243996901627
# Try k=96 on valid data, AUC: 0.9527498063516654
# Try k=97 on valid data, AUC: 0.9527498063516654
# Try k=98 on valid data, AUC: 0.9523625096824168
# Try k=99 on valid data, AUC: 0.953137103020914
# Try k=100 on valid data, AUC: 0.9527498063516654
# Try k=101 on valid data, AUC: 0.953137103020914
# Try k=102 on valid data, AUC: 0.9523625096824168
# Try k=103 on valid data, AUC: 0.9523625096824168
# Try k=104 on valid data, AUC: 0.9515879163439194
# Try k=105 on valid data, AUC: 0.951975213013168
# Try k=106 on valid data, AUC: 0.9515879163439194
# Try k=107 on valid data, AUC: 0.9523625096824168
# Try k=108 on valid data, AUC: 0.9515879163439194
# Best k: 2, AUC on valid data: 0.9774305436548465

# %%
k = best_knn[1]
knn = best_knn[2]
def evaluate_model(model, X, y):
    predicted_y = model.predict(X)
    auc = roc_auc_score(y, predicted_y)
    print(f"Model AUC: {auc}")
    print(classification_report(y, predicted_y))
    confusion_mat = confusion_matrix(y, predicted_y)
    print(f"Confusion matrix: \n{confusion_mat}")
print("Evaluating knn on train data:")
evaluate_model(knn, train_X, train_y)
print("Evaluating knn on test data:")
evaluate_model(knn, test_X, test_y)
# Out:
# Evaluating knn on train data:
# Model AUC: 0.9948730879139351
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5949
#            1       1.00      0.99      0.99      5949
#
#     accuracy                           0.99     11898
#    macro avg       0.99      0.99      0.99     11898
# weighted avg       0.99      0.99      0.99     11898
#
# Confusion matrix:
# [[5949    0]
#  [  61 5888]]
# Evaluating knn on test data:
# Model AUC: 0.9689777755044627
#               precision    recall  f1-score   support
#
#            0       0.81      0.96      0.88       122
#            1       1.00      0.98      0.99      1282
#
#     accuracy                           0.98      1404
#    macro avg       0.90      0.97      0.93      1404
# weighted avg       0.98      0.98      0.98      1404
#
# Confusion matrix:
# [[ 117    5]
#  [  27 1255]]

# %%
lr = LogisticRegression()
lr.fit(train_X, train_y)
predicted_y = lr.predict(valid_X)
auc = roc_auc_score(valid_y, predicted_y)
print(f"AUC on valid data: {auc}")

print("Evaluating logistic regression on train data:")
evaluate_model(lr, train_X, train_y)
print("Evaluating logistic regression on test data:")
evaluate_model(lr, test_X, test_y)
# Out:
# AUC on valid data: 0.7450456872973548
# Evaluating logistic regression on train data:
# Model AUC: 0.7428139183055976
#               precision    recall  f1-score   support
#
#            0       0.78      0.68      0.73      5949
#            1       0.72      0.81      0.76      5949
#
#     accuracy                           0.74     11898
#    macro avg       0.75      0.74      0.74     11898
# weighted avg       0.75      0.74      0.74     11898
#
# Confusion matrix:
# [[4039 1910]
#  [1150 4799]]
# Evaluating logistic regression on test data:
# Model AUC: 0.6971880514564844
#               precision    recall  f1-score   support
#
#            0       0.22      0.59      0.32       122
#            1       0.95      0.80      0.87      1282
#
#     accuracy                           0.79      1404
#    macro avg       0.59      0.70      0.60      1404
# weighted avg       0.89      0.79      0.82      1404
#
# Confusion matrix:
# [[  72   50]
#  [ 251 1031]]
