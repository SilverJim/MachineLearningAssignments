# %%
import numpy as np # import the Numpy library and rename it as "np"
import pandas as pd # Import the Pandas library and rename it as "pd"
import sys # Import the sys module
import math # Import the math module
# Import functions from sklearn
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix
# Import a tool for handling class imbalance issues through oversampling
from imblearn.over_sampling import RandomOverSampler

# %%
data_filename = 'AirQualityUCI.csv'  # Define the name of the data file to be loaded

# Check if the code is running in a Google Colab environment
if sys.modules.get("google.colab") is None:
    data_path_prefix = "."  # If not in Colab, set the data path prefix to the current directory
else:
    from google.colab import drive
    drive.mount("/content/drive")  # Mount Google Drive in Colab
    data_path_prefix = "/content/drive/MyDrive/MachineLearningAssignment/Assignment1"  # Set the data path prefix to the Google Drive location

# Build the full data path
data_path = f"{data_path_prefix}/{data_filename}"

print(f"Loading data from data path: {data_path}")

# Read the data from the CSV file using Pandas, specifying the separator as ';' and treating -200 as NaN values(The data source has indicated that -200 is a missing value.)
df = pd.read_csv(data_path, sep=';', na_values=-200)

# Display the loaded DataFrame (data)
df
# Out:
# Loading data from data path: ./AirQualityUCI.csv
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# ...

# %%
# Show rows with missing values
df[df.loc[:,~df.columns.str.contains("Unnamed:")].isnull().any(axis=1)]
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 9     11/03/2004  03.00.00    0,6       1010.0      19.0      1,7
# 10    11/03/2004  04.00.00    NaN       1011.0      14.0      1,3
# 33    12/03/2004  03.00.00    0,8        889.0      21.0      1,9
# 34    12/03/2004  04.00.00    NaN        831.0      10.0      1,1
# 39    12/03/2004  09.00.00    NaN       1545.0       NaN     22,1
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9             561.0      NaN        1705.0      NaN        1235.0
# ...

# %%
processed_df = df.copy()  # Create a new data copy for processing

# Remove completely empty rows and columns
processed_df.dropna(how='all', axis=1, inplace=True)
processed_df.dropna(how='all', axis=0, inplace=True)

# For each column starting from the third column
for column in processed_df.columns[2:]:
    # If the column's data type is object (string)
    if processed_df[column].dtype == object:
        # Replace commas with periods and convert the data type to float
        processed_df[column] = processed_df[column].str.replace(",", ".").astype(float)

# Create a new column named "DateTime" by merging the "Date" and "Time" columns into a datetime format and delete the old one.
processed_df["DateTime"] = pd.to_datetime(processed_df["Date"].str.cat(processed_df["Time"], sep=" "), format="%d/%m/%Y %H.%M.%S")
processed_df.drop(["Date", "Time"], axis=1, inplace=True)

# Show rows with missing values
processed_df[processed_df.isnull().any(axis=1)]
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 9        0.6       1010.0      19.0       1.7          561.0      NaN
# 10       NaN       1011.0      14.0       1.3          527.0     21.0
# 33       0.8        889.0      21.0       1.9          574.0      NaN
# 34       NaN        831.0      10.0       1.1          506.0     21.0
# 39       NaN       1545.0       NaN      22.1         1353.0      NaN
# ...      ...          ...       ...       ...            ...      ...
# 9352     3.1       1314.0       NaN      13.5         1101.0    472.0
# 9353     2.4       1163.0       NaN      11.4         1027.0    353.0
# 9354     2.4       1142.0       NaN      12.4         1063.0    293.0
# 9355     2.1       1003.0       NaN       9.5          961.0    235.0
# 9356     2.2       1071.0       NaN      11.9         1047.0    265.0
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  \
# ...

# %%
processed_df.isnull().sum() # Calculate the number of missing (NaN) values in each column
# Out:
# CO(GT)           1592
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)            0
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# DateTime            0
# dtype: int64

# %%
# Drop rows with at least 9 non-null values
processed_df.dropna(axis=0, thresh=9, inplace=True)

# Drop the "DateTime" and "NMHC(GT)" column
processed_df.drop("DateTime", axis=1, inplace=True)
processed_df.drop("NMHC(GT)", axis=1, inplace=True)

# Fill missing values with the mean of each column
processed_df.fillna(processed_df.mean(), inplace=True)

# Define the tag column name
tag_column = "C6H6(GT)"

# Move target column to the last column
temp = processed_df.pop(tag_column)
processed_df[tag_column] = temp

# Display the resulting DataFrame
processed_df
# Out:
#       CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# 0        2.6       1360.0         1046.0    166.0        1056.0    113.0
# 1        2.0       1292.0          955.0    103.0        1174.0     92.0
# 2        2.2       1402.0          939.0    131.0        1140.0    114.0
# 3        2.2       1376.0          948.0    172.0        1092.0    122.0
# 4        1.6       1272.0          836.0    131.0        1205.0    116.0
# ...      ...          ...            ...      ...           ...      ...
# 9352     3.1       1314.0         1101.0    472.0         539.0    190.0
# 9353     2.4       1163.0         1027.0    353.0         604.0    179.0
# 9354     2.4       1142.0         1063.0    293.0         603.0    175.0
# 9355     2.1       1003.0          961.0    235.0         702.0    156.0
# 9356     2.2       1071.0         1047.0    265.0         654.0    168.0
#
#       PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  C6H6(GT)
# ...

# %%
# Define a function to split the dataset into training, validation, and test sets
def data_split(df):
    # Split the original DataFrame into a training set (70%) and a combined validation and test set (30%)
    train_df, valid_and_test_df = train_test_split(df, train_size=0.7, random_state=0)

    # Further split the validation and test set into a validation set (50%) and a test set (50%)
    valid_df, test_df = train_test_split(valid_and_test_df, train_size=0.5, random_state=0)

    # Return the three sets: training, validation, and test
    return train_df, valid_df, test_df

# Call the data_split function with the 'processed_df' DataFrame as input and store the results in separate variables
train_df, valid_df, test_df = data_split(processed_df)

# Display the training
train_df
# Out:
#        CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)     NOx(GT)  PT08.S3(NOx)  \
# 1020 -0.31738        977.0          800.0  242.189292         990.0
# 3133  2.30000       1279.0         1197.0  250.000000         599.0
# 1163  0.50000        856.0          619.0   29.000000        1191.0
# 3858 -0.31738       1029.0          791.0  242.189292         855.0
# 6532  2.40000       1195.0         1013.0  355.000000         646.0
# ...       ...          ...            ...         ...           ...
# 4520 -0.31738        908.0          657.0  242.189292        1013.0
# 8256  2.40000       1172.0          977.0  280.000000         657.0
# 5007 -0.31738       1337.0         1339.0  242.189292         525.0
# 3343 -0.31738        860.0          847.0   58.000000         873.0
# 2811  1.80000       1058.0         1004.0   92.000000         776.0
#
#          NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  C6H6(GT)
# 1020  112.145137        1474.0        926.0  12.2  64.1  0.9062       5.7
# ...

# %%
# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler on the training data
scaler.fit(train_df)

# Define a function to scale a dataset and, optionally, perform classification and oversampling
def scale_dataset(scaler, classification_func=None):
    def func(df, oversample=False):
        # Transform the input DataFrame using the scaler
        data = scaler.transform(df)

        # Separate features (X) and target labels (y)
        X = data[:, :-1]
        y = data[:, -1]

        # If a classification function is provided, apply it to the target labels
        if classification_func is not None:
            y = np.array([classification_func(item) for item in y])

            # If oversampling is enabled, perform oversampling using RandomOverSampler
            if oversample:
                ros = RandomOverSampler(random_state=0)
                X, y = ros.fit_resample(X, y)

        # Return the scaled data, X, and y
        return data, X, y

    return func

# %%
# Define a classification function using a lambda function. It classifies values greater than 0 as 1, and others as 0
classification_func = lambda x: 1 if x > 0 else 0

# Create a scaled dataset using the previously defined scaler and classification function
scale_classification = scale_dataset(scaler, classification_func)

# Apply the scaled dataset function to the training data and oversample it
train, train_X, train_y = scale_classification(train_df, oversample=True)

# Apply the scaled dataset function to the validation data
valid, valid_X, valid_y = scale_classification(valid_df)

# Apply the scaled dataset function to the test data
test, test_X, test_y = scale_classification(test_df)

# %%
best_knn = None  # Initialize a variable to store the best KNN classifier
print(f"Length of train data: {len(train_X)}")

# Iterate over a range of only odd values for k
for k in range(1, int(math.sqrt(len(train_X))), 2):
    # Create a KNN classifier with 'k' neighbors
    knn = KNeighborsClassifier(n_neighbors=k)

    # Fit the KNN classifier on the training data
    knn.fit(train_X, train_y)

    # Predict the target labels on the validation data
    predicted_y = knn.predict(valid_X)

    # Calculate the ROC AUC score for the predicted labels on the validation data
    auc = roc_auc_score(valid_y, predicted_y)

    # Print the AUC score for the current 'k' value on the validation data
    print(f"Try k={k} on valid data, AUC: {auc}")

    # Update the best_knn variable if the current model has a higher AUC score
    if best_knn is None or auc > best_knn[0]:
        best_knn = (auc, k, knn)

# Print the best 'k' value and the corresponding AUC on the validation data
print(f"Best k: {best_knn[1]}, AUC on valid data: {best_knn[0]}")
# Out:
# Length of train data: 7530
# Try k=1 on valid data, AUC: 0.9601114471326164
# Try k=3 on valid data, AUC: 0.9590205439814815
# Try k=5 on valid data, AUC: 0.9609736689814816
# Try k=7 on valid data, AUC: 0.9682459677419355
# Try k=9 on valid data, AUC: 0.9633631552419355
# Try k=11 on valid data, AUC: 0.9596179155465949
# Try k=13 on valid data, AUC: 0.9631449746117086
# Try k=15 on valid data, AUC: 0.9674875858721624
# Try k=17 on valid data, AUC: 0.966131832437276
# Try k=19 on valid data, AUC: 0.961789221176822
# Try k=21 on valid data, AUC: 0.9588595336768219
# Try k=23 on valid data, AUC: 0.9610308393070489
# Try k=25 on valid data, AUC: 0.958641353046595
# Try k=27 on valid data, AUC: 0.9570674189814816
# Try k=29 on valid data, AUC: 0.9551142939814815
# Try k=31 on valid data, AUC: 0.9547351030465949
# Try k=33 on valid data, AUC: 0.953540359916368
# Try k=35 on valid data, AUC: 0.954298741786141
# Try k=37 on valid data, AUC: 0.9556544952210274
# ...

# %%
k = best_knn[1]  # Get the best 'k' value from the best_knn
knn = best_knn[2]  # Get the best KNN classifier from the best_knn

# Define a function to evaluate a model's performance
def evaluate_model(model, X, y):
    # Make predictions on the input data
    predicted_y = model.predict(X)

    # Calculate the ROC AUC  to evaluate the model's performance
    auc = roc_auc_score(y, predicted_y)

    # Print the ROC AUC
    print(f"Model AUC: {auc}")

    # Print a classification report with additional performance metrics
    print(classification_report(y, predicted_y))

    # Calculate and print the confusion matrix
    confusion_mat = confusion_matrix(y, predicted_y)
    print(f"Confusion matrix: \n{confusion_mat}")

# Evaluate the best KNN model on the training data
print("Evaluating KNN on train data:")
evaluate_model(knn, train_X, train_y)

# Evaluate the best KNN model on the test data
print("Evaluating KNN on test data:")
evaluate_model(knn, test_X, test_y)
# Out:
# Evaluating KNN on train data:
# Model AUC: 0.9784860557768924
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      3765
#            1       0.98      0.98      0.98      3765
#
#     accuracy                           0.98      7530
#    macro avg       0.98      0.98      0.98      7530
# weighted avg       0.98      0.98      0.98      7530
#
# Confusion matrix:
# [[3673   92]
#  [  70 3695]]
# Evaluating KNN on test data:
# Model AUC: 0.9622409359317073
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       822
#            1       0.94      0.97      0.95       527
#
#     accuracy                           0.96      1349
#    macro avg       0.96      0.96      0.96      1349
# weighted avg       0.96      0.96      0.96      1349
#
# Confusion matrix:
# [[788  34]
#  [ 18 509]]

# %%
# Create a Logistic Regression classifier
lr = LogisticRegression()

# Fit the Logistic Regression model on the training data
lr.fit(train_X, train_y)

# Predict the target labels on the validation data
predicted_y = lr.predict(valid_X)

# Calculate the ROC AUC for the predicted labels on the validation data
auc = roc_auc_score(valid_y, predicted_y)

# Print the AUC on the validation data
print(f"AUC on valid data: {auc}")

# Evaluate the Logistic Regression model on the training data
print("Evaluating logistic regression on train data:")
evaluate_model(lr, train_X, train_y)

# Evaluate the Logistic Regression model on the test data
print("Evaluating logistic regression on test data:")
evaluate_model(lr, test_X, test_y)
# Out:
# AUC on valid data: 0.9914757877837516
# Evaluating logistic regression on train data:
# Model AUC: 0.9911022576361221
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      3765
#            1       0.99      0.99      0.99      3765
#
#     accuracy                           0.99      7530
#    macro avg       0.99      0.99      0.99      7530
# weighted avg       0.99      0.99      0.99      7530
#
# Confusion matrix:
# [[3719   46]
#  [  21 3744]]
# Evaluating logistic regression on test data:
# Model AUC: 0.9920197417323415
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       822
#            1       0.98      1.00      0.99       527
#
#     accuracy                           0.99      1349
#    macro avg       0.99      0.99      0.99      1349
# weighted avg       0.99      0.99      0.99      1349
#
# Confusion matrix:
# [[812  10]
#  [  2 525]]
